# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Nav33dCodes/flyrank-ml-internship-naveed/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# **Content Refresh Prioritization**
#
# ## My Lane
#
# I am choosing the Content Refresh Prioritization lane.
#
# I want to study which existing pages should be reviewed and refreshed first based on their observed search performance. This lane is useful because a content team may have thousands of pages but limited time, so they need a practical way to decide which pages deserve attention first.
#
# ## Research Question
#
# Which pages should a content team review first for a possible content refresh based on declining search performance and available page-level signals?
#
# ## Decision, Action, and Cost of a Wrong Call
#
# **Unit of analysis:** One webpage.
#
# **Decision:** Decide which pages should receive priority for manual review and possible content refresh.
#
# **Output:** A ranked list of pages, where pages with stronger evidence of declining performance appear near the top.
#
# **Action:** A content or SEO team reviews the highest-ranked pages and decides whether to update, improve, consolidate, or leave them unchanged.
#
# **Cost of a wrong recommendation:** If a healthy page is incorrectly ranked as high priority, the team may waste time editing content that did not need attention. If a genuinely declining page is missed, the team may delay an important refresh and lose more search traffic.
#
# **Why data or ML can help:** A team cannot manually compare thousands of pages consistently. Data analysis can combine several observed signals and help prioritize pages for human review. The result should support a decision, not replace human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Assuming the dataset is named 'data.csv' or similar.
# Please replace 'data.csv' with the actual filename of your starter dataset.
df = pd.read_csv('data.csv')

# Quick supporting numbers from the starter dataset

print("Total pages:", len(df))

print(
    "Pages with a declining trend:",
    (df["trend_direction"] == "down").sum()
)

print(
    "Percentage of pages with a declining trend:",
    round((df["trend_direction"] == "down").mean() * 100, 2),
    "%"
)

print(
    "Median impressions in the last 90 days:",
    round(df["impressions_90d"].median(), 2)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1230/2877984833.py in <cell line: 0>()
#       1 # Quick supporting numbers from the starter dataset
#       2
# ----> 3 print("Total pages:", len(df))
#       4
#       5 print(
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
